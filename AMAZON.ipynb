# %%
# %ls
# Out:
#  07_02_pie_box_scatter_bubble.ipynb   requirements.txt
#  Amazon.csv                           runtime.txt
#  Canada.xlsx                          Untitled1.ipynb
#  clase3.ipynb                         Untitled2.ipynb
#  nhanes_2015_2016.csv                 Untitled.ipynb
# 'pivot tables.ipynb'                 'welcome_binder (1).ipynb'
#  README.md                            welcome_binder.ipynb
#  requierementsEXL

# %%
# %ls datasets/
# Out:
# ls: cannot access 'datasets/': No such file or directory

# %%
import pandas as pd
import numpy as np

# %%
path = 'Amazon.csv'
df = pd.read_csv(path)
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083   1.427083  18853200

# %%
df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 6130  2021-09-23  3380.050049  3428.959961  3380.050049  3416.000000
# 6131  2021-09-24  3402.010010  3429.260010  3393.399902  3425.520020
# 6132  2021-09-27  3371.500000  3415.570068  3339.610107  3405.800049
# 6133  2021-09-28  3357.709961  3369.189941  3290.100098  3315.959961
# 6134  2021-09-29  3322.110107  3351.300049  3298.000000  3324.547119
#
#         Adj Close   Volume
# 6130  3416.000000  2379400
# 6131  3425.520020  2113600
# 6132  3405.800049  3634500
# 6133  3315.959961  4425600
# 6134  3324.547119  1893888

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.iloc[20:,:6]
# Out:
#             Date         Open         High          Low        Close  \
# 20    1997-06-13     1.625000     1.625000     1.583333     1.583333
# 21    1997-06-16     1.604167     1.604167     1.562500     1.572917
# 22    1997-06-17     1.598958     1.598958     1.494792     1.505208
# 23    1997-06-18     1.520833     1.536458     1.500000     1.510417
# 24    1997-06-19     1.510417     1.531250     1.500000     1.510417
# ...          ...          ...          ...          ...          ...
# 6130  2021-09-23  3380.050049  3428.959961  3380.050049  3416.000000
# 6131  2021-09-24  3402.010010  3429.260010  3393.399902  3425.520020
# 6132  2021-09-27  3371.500000  3415.570068  3339.610107  3405.800049
# 6133  2021-09-28  3357.709961  3369.189941  3290.100098  3315.959961
# 6134  2021-09-29  3322.110107  3351.300049  3298.000000  3324.547119
#
#         Adj Close
# 20       1.583333
# 21       1.572917
# 22       1.505208
# 23       1.510417
# 24       1.510417
# ...           ...
# ...

# %%
df.loc[:3, [ 'Date', 'High', 'Close']]
# Out:
#          Date      High     Close
# 0  1997-05-15  2.500000  1.958333
# 1  1997-05-16  1.979167  1.729167
# 2  1997-05-19  1.770833  1.708333
# 3  1997-05-20  1.750000  1.635417

# %%
my_pivot = pd.pivot_table (df,
               index = 'Open',
                           values = 'Low',
                           aggfunc= 'sum',
                           columns = 'High',
                           margins = True
                
                    )
                          
my_pivot.head(5)
# Out:
# High      1.447917  1.489583  1.510417  1.515625  1.520833  1.526042  1.53125  \
# Open
# 1.406250       NaN       NaN       NaN       NaN  1.333333       NaN      NaN
# 1.416667       NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 1.437500    1.3125       NaN       NaN       NaN       NaN       NaN      NaN
# 1.479167       NaN  1.395833       NaN       NaN       NaN       NaN      NaN
# 1.500000       NaN       NaN  1.479167       NaN       NaN       NaN      NaN
#
# High      1.536458  1.541667  1.552083  ...  3695.399902  3698.5  3712.080078  \
# Open                                    ...
# 1.406250       NaN       NaN       NaN  ...          NaN     NaN          NaN
# 1.416667       NaN     1.375       NaN  ...          NaN     NaN          NaN
# 1.437500       NaN       NaN       NaN  ...          NaN     NaN          NaN
# 1.479167       NaN       NaN       NaN  ...          NaN     NaN          NaN
# ...
