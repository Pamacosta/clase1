# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %ls
# Out:
#  07_02_pie_box_scatter_bubble.ipynb   Institution.ipynb
#  adult.csv                            integrantes_ensanut2020_w.csv
#  Amazon.csv                           mic.xlsx
#  AMAZON.ipynb                         nhanes_2015_2016.csv
#  antropometria-dataset-2.csv         'pivot tables.ipynb'
# 'archive (2).zip'                     README.md
#  Canada.xlsx                          requierementsEXL
#  clase3.ipynb                         requirements.txt
# 'clase 4.2.ipynb'                     runtime.txt
#  clase4.ipynb                         tokyo_2021.csv
# 'clase 5.ipynb'                       TOKYO2021.ipynb
#  coches-variables.xlsx                Untitled1.ipynb
#  covid19Vaccination.xlsx              Untitled.ipynb
#  cwurData.csv                        'welcome_binder (1).ipynb'
# 'Encuesta Clase 7.ipynb'              welcome_binder.ipynb
#  headbrain.csv                       'World Universities Ranking.ipynb'
# 'Institution (1).ipynb'

# %% [markdown]
# ## 1. Existe alguna relación entre Head Size(cm^3) vs Brain Weight(grams)

# %%
df= pd.read_csv('headbrain.csv')
df.head()

x = df['Head Size(cm^3)']
y = df['Brain Weight(grams)']

np.corrcoef (x,y)
# Out:
# array([[1.        , 0.79956971],
#        [0.79956971, 1.        ]])

# %%
colors = {1: 'red', 2: 'green'}
plt.figure(figsize = (13,10))
plt.scatter(x,y,
            c= df['Gender'].map(colors),
            marker = 'x',
            s = 175
           )
plt.xlabel('Head Size(cm^3)', fontweight = 'regular', color = 'black',
fontsize = 18, horizontalalignment = 'center')
plt.ylabel('Brain Weight(grams)',fontweight = 'regular', color = 'black',
fontsize = 18, horizontalalignment = 'center')
# Out:
# Text(0, 0.5, 'Brain Weight(grams)')

# %% [markdown]
# #### Conclusión:
# La coeficiente de correlación es 0.7995. Se puede decir que existe una correlacciónmuy fuerte entre las variabels head size vs Brain Weight

# %%
import numpy as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
pip install statsmodels
# Out:
# ...
#      |████████████████████████████████| 9.9 MB 4.1 MB/s eta 0:00:01     |████▎                           | 1.3 MB 4.1 MB/s eta 0:00:03
# ...
#      |████████████████████████████████| 233 kB 63.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
model = sm.OLS.from_formula ('y~x',
                             data = df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.639
# Model:                            OLS   Adj. R-squared:                  0.638
# Method:                 Least Squares   F-statistic:                     416.5
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           5.96e-54
# Time:                        13:47:51   Log-Likelihood:                -1350.3
# No. Observations:                 237   AIC:                             2705.
# Df Residuals:                     235   BIC:                             2711.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    325.5734     47.141      6.906      0.000     232.701     418.446
# ...
