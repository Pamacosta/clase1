# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %% [markdown]
# print ('hola')

# %%
import

# %%
import numpy as np

# %%
N = 50
x = np.random, rand (N)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_145/1238174736.py in <module>
#       1 N = 50
# ----> 2 x = np.random, rand (N)
#       3 x
#
# NameError: name 'rand' is not defined

# %%
N = 50
x = np.random, rand(N)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_145/146518313.py in <module>
#       1 N = 50
# ----> 2 x = np.random, rand(N)
#       3 x
#
# NameError: name 'rand' is not defined

# %%
N = 50
x = np.random, rand (N)
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_145/197766724.py in <module>
#       1 N = 50
# ----> 2 x = np.random, rand (N)
#       3 X
#
# NameError: name 'rand' is not defined

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(nombre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_145/3120047230.py in <module>
# ----> 1 type(nombre)
#
# NameError: name 'nombre' is not defined

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
type(none)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_145/4013139472.py in <module>
# ----> 1 type(none)
#
# NameError: name 'none' is not defined

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(2/3)
# Out:
# float

# %%
numbers = [1,2,3,4,5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
suma = sum(numbers)
suma
# Out:
# 15

# %%
lenght_numbers = len(numbers)
lenght_numbers
# Out:
# 5

# %%
type(numbers)
# Out:
# list

# %%
promedio = suma/lenght_numbers
promedio
# Out:
# 3.0

# %%
60*10**(-2)
# Out:
# 0.6

# %%
type (bool('yes'))
# Out:
# bool

# %%
type('yes')
# Out:
# str

# %%
type(6<5)
# Out:
# bool

# %%
a_list = [True, 6<5, 1==3, None is None, 2, 'Name' ]
a_list
# Out:
# [True, False, False, True, 2, 'Name']

# %%
print (2+5)
# Out:
# 7

# %%
x = 5
y = 6
if x<y:
    print ('{} es menor que {}'.format(x,y))
else: 
           print('{} es mayor que {}'.format(x,y))
# Out:
# 15 es mayor que 6

# %%
if x<y:
    print (x,'es menor que')
